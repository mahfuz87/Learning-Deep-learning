# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy
# Out:
# Using TensorFlow backend.

# %%
seed = 5
numpy.random.seed(seed)

# %%
dataset = numpy.loadtxt('pima-indians-diabetes.csv', delimiter=',')
x = dataset[:,0:8]
y = dataset [:,8]

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Checkpoint Model Improvements
filepath = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callback_list = [checkpoint]
model.fit(x, y, validation_split=.33, epochs=150, batch_size=10, callbacks=callback_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.79134, saving model to weights-improvement-01-0.79.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.79134
#
# Epoch 00003: val_accuracy did not improve from 0.79134
#
# Epoch 00004: val_accuracy improved from 0.79134 to 0.79921, saving model to weights-improvement-04-0.80.hdf5
#
# Epoch 00005: val_accuracy did not improve from 0.79921
#
# Epoch 00006: val_accuracy did not improve from 0.79921
#
# Epoch 00007: val_accuracy did not improve from 0.79921
#
# Epoch 00008: val_accuracy improved from 0.79921 to 0.80315, saving model to weights-improvement-08-0.80.hdf5
#
# Epoch 00009: val_accuracy did not improve from 0.80315
#
# Epoch 00010: val_accuracy did not improve from 0.80315
#
# Epoch 00011: val_accuracy did not improve from 0.80315
#
# Epoch 00012: val_accuracy did not improve from 0.80315
#
# Epoch 00013: val_accuracy did not improve from 0.80315
#
# Epoch 00014: val_accuracy did not improve from 0.80315
#
# ...

# %%
#Checkpoint Best Model Only
filepath = 'weights.best.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callback_list = [checkpoint]
model.fit(x, y, validation_split=.33, epochs=150, batch_size=10, callbacks=callback_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.79921, saving model to weights.best.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.79921
#
# Epoch 00003: val_accuracy improved from 0.79921 to 0.80315, saving model to weights.best.hdf5
#
# Epoch 00004: val_accuracy did not improve from 0.80315
#
# Epoch 00005: val_accuracy improved from 0.80315 to 0.81102, saving model to weights.best.hdf5
#
# Epoch 00006: val_accuracy did not improve from 0.81102
#
# Epoch 00007: val_accuracy did not improve from 0.81102
#
# Epoch 00008: val_accuracy did not improve from 0.81102
#
# Epoch 00009: val_accuracy did not improve from 0.81102
#
# Epoch 00010: val_accuracy did not improve from 0.81102
#
# Epoch 00011: val_accuracy did not improve from 0.81102
#
# Epoch 00012: val_accuracy did not improve from 0.81102
#
# Epoch 00013: val_accuracy did not improve from 0.81102
#
# Epoch 00014: val_accuracy did not improve from 0.81102
#
# Epoch 00015: val_accuracy did not improve from 0.81102
#
# ...

# %%
#loading the saved model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
model.load_weights('weights.best.hdf5')
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
scores = model.evaluate(x, y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 81.64%
